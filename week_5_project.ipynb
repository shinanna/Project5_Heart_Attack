# %%
import pandas as pd
import numpy as np
import streamlit as st
import seaborn as sns
import matplotlib.pyplot as plt

heart = pd.read_csv("/Users/bene/Downloads/heart.csv")
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart.describe()

# %%
# Potential problem on ca
heart["ca"].value_counts() # We get 5 (0-4) different values instead of 4 (0-3)
heart[heart["ca"] == 4]
# Out:
# 2022-01-14 11:42:01.617 INFO    numexpr.utils: NumExpr defaulting to 8 threads.
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 92    52    1   2       138   223    0        1      169      0      0.0
# 158   58    1   1       125   220    0        1      144      0      0.4
# 163   38    1   2       138   175    0        1      173      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
# 251   43    1   0       132   247    1        0      143      1      0.1
#
#      slope  ca  thal  target
# 92       2   4     2       1
# 158      1   4     3       1
# 163      2   4     2       1
# 164      2   4     2       1
# 251      1   4     3       0

# %%
# Potential problem on thal
heart["thal"].value_counts() # We get 4 different values (0-3) when we're supposed to get only three (0-2)
#heart[heart["thal"] == 3]
#heart["thal"].plot.hist()
# Out:
# 2    166
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64

# %%
# Potential problem on oldpeak
heart["oldpeak"].value_counts()
# Out:
# 0.0    99
# 1.2    17
# 1.0    14
# 0.6    14
# 0.8    13
# 1.4    13
# 0.2    12
# 1.6    11
# 1.8    10
# 0.4     9
# 2.0     9
# 0.1     7
# 2.6     6
# 2.8     6
# 1.9     5
# 0.5     5
# 1.5     5
# 3.0     5
# 2.2     4
# 3.6     4
# 0.3     3
# 2.4     3
# 0.9     3
# 4.0     3
# 3.4     3
# 2.3     2
# 1.1     2
# 4.2     2
# 3.2     2
# 2.5     2
# 3.5     1
# 1.3     1
# 3.8     1
# 6.2     1
# 5.6     1
# 3.1     1
# 2.9     1
# 4.4     1
# 0.7     1
# 2.1     1
# Name: oldpeak, dtype: int64

# %%
plt.figure(figsize=[10, 10])
sns.heatmap(heart.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
malades = heart[(heart["cp"] == 1) & (heart["restecg"] == 0) & (heart["target"] == 1)]

# %%
malades
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 2     41    0   1       130   204    0        0      172      0      1.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 32    44    1   1       130   219    0        0      188      0      0.0
# 41    48    1   1       130   245    0        0      180      0      0.2
# 67    45    0   1       130   234    0        0      175      0      0.6
# 72    29    1   1       130   204    0        0      202      0      0.0
# 75    55    0   1       135   250    0        0      161      0      1.4
# 81    45    1   1       128   308    0        0      170      0      0.0
# 93    54    0   1       132   288    1        0      159      1      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
# 137   62    1   1       128   208    1        0      140      0      0.0
# 145   70    1   1       156   245    0        0      143      0      0.0
# ...

# %%
plt.figure(figsize=[10, 10])
sns.heatmap(malades.corr(), annot=True)
# Out:
# <AxesSubplot:>
